# %%
import matplotlib
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
import matplotlib.pyplot as plt
import ScaffoldGridWorld_env 
from replay_buffer import ReplayBuffer
import gymnasium as gym
import random
import math
from itertools import count

device = "cuda" if torch.cuda.is_available() else "cpu"
is_ipython = "inline" in matplotlib.get_backend()
if is_ipython:
    from IPython import display
    
from collections import deque, namedtuple

Transition = namedtuple("Transition", ("state", "action", "next_state", "reward"))

# %%
CHECKPOINT_NUMBER = 2600
BATCH_SIZE = 64
GAMMA = 0.99
EPS_START = 0.99
EPS_END = 0.01
EPS_DECAY = 5500000
TAU = 0.0002
STEPSIZE = 0.00005
BETA_START = 0.4
BETA_END = 1
BETA_LINEAR_CAP = 5500 * 1500
N_STEP = 1

steps_done = 3000 * CHECKPOINT_NUMBER
print(0.01 + (0.99 - 0.01) * math.exp(-1. * steps_done / EPS_DECAY))
# Out:
# 0.2473108187633607

# %%
#class DoubleDueling_DQN(nn.Module):
#    def __init__(self, input_dim, action_dim):
#        
#        super(DoubleDueling_DQN, self).__init__()
#        self.conv1 = nn.Conv3d(3, 29, 3, 1, 1)
#        self.conv2 = nn.Conv3d(32, 67, 3, 1, 1)
#        
#        self.fc1 = nn.Linear((64 + 3*2)*input_dim * input_dim * input_dim, 1024)
#        
#        self.lstmcell = nn.LSTMCell(1024, 1024)
#        
#        self.actions = nn.Linear(2048, action_dim)
#        self.advantage = nn.Linear(2048, 1)
#    def forward(self, x, h, c):
#        original_state = x
#                    
#        x = self.conv1(x)
#        x = torch.cat([x, original_state], dim=1)
#        x = F.gelu(x)
#        
#        x = self.conv2(x)
#        x = torch.cat([x, original_state], dim=1)
#        x = F.gelu(x)
#        
#        x = nn.Flatten()(x)
#        x = self.fc1(x)
#        x = F.gelu(x)
#        
#        h, c = self.lstmcell(x, (h, c))
#        
#        actions = self.actions(torch.cat([h, x], dim=1))
#        advantage = self.advantage(torch.cat([h, x], dim=1))
#        x = advantage + (actions - actions.mean(dim=1, keepdim=True))
#        return x, h, c


class DoubleDueling_DQN(nn.Module):
    def __init__(self, input_dim, action_dim):
        
        super(DoubleDueling_DQN, self).__init__()
        self.conv1 = nn.Conv3d(3, 29, 3, 1, 1)
        self.conv2 = nn.Conv3d(32, 67, 3, 1, 1)
        
        self.fc1 = nn.Linear((64 + 3*2)*input_dim * input_dim * input_dim, 1024)
        
        self.lstmcell = nn.LSTMCell(1024, 1024)
        
        self.actions = nn.Linear(2048, action_dim)
        self.advantage = nn.Linear(2048, 1)
    def forward(self, x, h, c):
        original_state = x
                    
        x = self.conv1(x)
        x = torch.cat([x, original_state], dim=1)
        x = F.gelu(x)
        
        x = self.conv2(x)
        x = torch.cat([x, original_state], dim=1)
        x = F.gelu(x)
        
        x = nn.Flatten()(x)
        x = self.fc1(x)
        x = F.gelu(x)
        
        h, c = self.lstmcell(x, (h, c))
        
        actions = self.actions(torch.cat([h, x], dim=1))
        advantage = self.advantage(torch.cat([h, x], dim=1))
        x = advantage + (actions - actions.mean(dim=1, keepdim=True))
        return x, h, c

# %%
n_actions = 10
env = gym.make("ScaffoldGridWorld_env/ScaffoldGridWorld", dimension_size=6, path="targets")
env.reset()

policy_net = DoubleDueling_DQN(6, n_actions).to(device)
# Out:
# /home/truong/Documents/pytorch/myv/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be int64, actual type: float64
#   logger.warn(
# /home/truong/Documents/pytorch/myv/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")

# %%
policy_net = torch.load("checkpoint2600_policy.pt", map_location=torch.device("cpu"))

# %%
def select_action(state, h, c, greedy=False):
    #global steps_done
    
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * math.exp(-1. * steps_done / EPS_DECAY)
    #steps_done += 1
    
    if greedy:
        with torch.no_grad():
            out, h, c = policy_net(state, h, c)
            #print(out)
            return out.max(1).indices.view(1,1), h, c
            #return policy_net(state, h, c).max(1).indices.view(1,1), h, c
        
    if sample > eps_threshold:
        with torch.no_grad():
            out, h, c = policy_net(state, h, c)
            #print(out)
            
            return out.max(1).indices.view(1,1), h, c
    else:
        return torch.tensor([[env.action_space.sample()]], device=device, dtype=torch.long), h, c

# %%
state, info = env.reset()
class Action:
    FORWARD = 0
    BACKWARD = 1
    LEFT = 2
    RIGHT = 3
    UP = 4
    DOWN = 5
    PLACE_SCAFOLD = 6
    REMOVE_SCAFOLD = 7
    PLACE_BEAM = 8
    PLACE_COLUMN = 9

seq = [Action.PLACE_COLUMN, Action.FORWARD, Action.PLACE_SCAFOLD, Action.LEFT, Action.BACKWARD, Action.PLACE_SCAFOLD, 
       Action.BACKWARD, Action.RIGHT, Action.PLACE_SCAFOLD, Action.RIGHT, Action.FORWARD, Action.PLACE_SCAFOLD, 
       Action.UP, Action.LEFT, Action.PLACE_COLUMN, Action.LEFT]

for  a  in seq:
    state, reward, done, info,_ = env.step((a, 0))
    env.unwrapped.render()                                                                                                                                                         
    display.clear_output(wait=True)

# %%
colseq  = [0, 3,       9, 1, 6, 0, 2, 6, 3, 0, 6, 1, 3, 6, 2, 4,       9, 1, 6, 0, 2, 6, 3, 0, 6, 1, 3, 6, 2, 4, 
           9, 1, 6, 0, 2, 6, 3, 0, 6, 1, 3, 6, 2, 4]

seq = [0, 3,  9, 1, 6, 0,  2, 6, 3, 0, 6, 1, 3, 6, 2, 4,   9, 0]

s, m = env.reset()
env.unwrapped.AgentsPos[0] = [0, 0, 0]

for a in seq:
    _, _, _, _, _ = env.step((a, 0))
    env.unwrapped.render()
    display.clear_output(wait=True)

#for a in colseq:
#    _, _, _, _, _ = env.step((a, 0))
#    env.unwrapped.render()
#    display.clear_output(wait=True)



#exit()

# %%
import time
#state, info = env.reset()
env.reset()
state = env.get_obs()
state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
h = torch.zeros(1, 1024, dtype=torch.float32, device=device)
c = torch.zeros(1, 1024, dtype=torch.float32, device=device)

counter = 0
for t in range(500):
    counter += 1
    print(counter)  
    action, h, c = select_action(state, h, c, False)
    observation, reward, terminated, truncated, _ = env.step((action.item(), 0))
    print(action.item())
    #reward = torch.tensor([reward], device=device)
    done = terminated or truncated

    if terminated:
        next_state = None
    else:
        next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

    state = next_state
    if terminated or truncated:
        break
    env.unwrapped.render()                                                                                                                                                         
    display.clear_output(wait=True)
# Out:
# 51
# 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 27
#      25 if terminated or truncated:
#      26     break
# ---> 27 env.unwrapped.render()
#      28 display.clear_output(wait=True)
#
# File ~/Documents/pytorch/Deep-Reinforcement-Learning-agent-for-Construction-Project-Execution/ScaffoldGridWorld-env/ScaffoldGridWorld_env/envs/grid_world.py:742, in ScaffoldGridWorldEnv.render(self)
#     739 ax = fig.add_subplot(1, 2, 2, projection='3d')
#     740 ax.voxels(target_render, facecolors=colors, edgecolor='k')
# --> 742 plt.show()
#
# File ~/Documents/pytorch/myv/lib/python3.10/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
# ...

# %%
state, info = env.reset()
state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
h = torch.zeros(1, 1024, dtype=torch.float32, device=device)
c = torch.zeros(1, 1024, dtype=torch.float32, device=device)

seq = []
counter = 0
for t in count():
    print(state.shape) 
    action, h, c = select_action(state, h, c, True)
    
    observation, reward, terminated, truncated, _ = env.step((action.item(), 0))
    print(action.item())
    reward = torch.tensor([reward], device=device)
    done = terminated or truncated

    if terminated:
        next_state = None
    else:
        next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

    state = next_state
    if terminated or truncated:
        break
    env.unwrapped.render()                                                                                                                                                         
    #sleep(2)
    display.clear_output(wait=True)
    seq.append(action.item())
    counter += 1
    print(counter)
# Out:
# 17
# torch.Size([1, 3, 6, 6, 6])
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 25
#      23 if terminated or truncated:
#      24     break
# ---> 25 env.unwrapped.render()
#      26 #sleep(2)
#      27 display.clear_output(wait=True)
#
# File ~/Documents/pytorch/Deep-Reinforcement-Learning-agent-for-Construction-Project-Execution/GridWorld-env/GridWorld_env/envs/grid_world.py:742, in GridWorldEnv.render(self)
#     739 ax = fig.add_subplot(1, 2, 2, projection='3d')
#     740 ax.voxels(target_render, facecolors=colors, edgecolor='k')
# --> 742 plt.show()
#
# File ~/Documents/pytorch/myv/lib/python3.10/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# ...
